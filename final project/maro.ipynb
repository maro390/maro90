# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from datetime import datetime

# %%
df = pd.read_csv(r"C:\Users\maraw\OneDrive\Desktop\final project\marawanRadi.csv")

df["ما هي الخدمات التعليمية التي تود الاشتراك أو الاستفسار عنها؟"] = df["ما هي الخدمات التعليمية التي تود الاشتراك أو الاستفسار عنها؟"].fillna('n/a')


df['date'] = pd.to_datetime(df['طابع زمني'])
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day
df.drop('طابع زمني', axis=1, inplace=True)

df.drop('date', axis=1, inplace=True)

# %%
df
# Out:
#             السنة الدراسية هل ترى التعليم عن بعد مفيد ومهم؟  \
# 0              الصف الثاني                              نعم
# 1      الصف الاول الاعدادي                              نعم
# 2              ثانيه ثانوي                               لا
# 3               اولي ثانوي                              نعم
# 4                ٣ ابتدائي                             ربما
# ..                     ...                              ...
# 145                  خريجة                              نعم
# 146             خريجة 2014                              نعم
# 147             اول إعدادي                              نعم
# 148  الصف الثانى الابتدائى                             ربما
# 149  الصف السادس الابتدائي                             ربما
#
#     ما هي الخدمات التعليمية التي تود الاشتراك أو الاستفسار عنها؟  \
# 0                                    القاعدة النورانية
# 1    كورس اللغة الإنجليزية, كورس اللغة الألمانية, م...
# 2       دبلومة البرمجة المتخصصة, كورس اللغة الإنجليزية
# ...

# %%
df['هل ترى التعليم عن بعد مفيد ومهم؟'].replace({'نعم' : 'Yes', 'لا' : "no", "ربما":"maybe"},inplace=True)
df["هل ترى التعليم عن بعد مفيد ومهم؟"].unique()
# Out:
# array(['Yes', 'no', 'maybe'], dtype=object)

# %%
def sucial(value):
    value_lower = value.lower()
    if re.search(r'fb|اعلان|فيس|face|بوست|إعلان',value_lower):
        return"Facebook"

    elif re.search(r'الانترنت|internet|net|النت|تواصل|ميديا',value_lower):
        return "social media"
    elif re.search(r'اليوتيوب',value_lower):
        return "youtube"
    elif re.search(r'اهلي|الاصدقاء|friend|الاقارب|صديق|اخت',value_lower):
        return "friend"
    else:
        return"N/A"
df["من أين علمت عن جينيس؟"] = df["من أين علمت عن جينيس؟"].astype(str)
df["من أين علمت عن جينيس؟"] = df["من أين علمت عن جينيس؟"].apply(sucial)
df["من أين علمت عن جينيس؟"].unique()
# Out:
# array(['Facebook', 'social media', 'friend', 'N/A', 'youtube'],
#       dtype=object)

# %%
import re

def funuii(value):
    value_lower = value.lower()

    if re.search(r'جريد|7|8|gr|5|سادس|صف|grade|جريد|جريد', value_lower):
        if re.search(r'1|١|ول', value_lower):
            return "first primary (Elementary School)"
        elif re.search(r'٢|2|ثان|تان', value_lower):
            return "second primary (Elementary School)"
        elif re.search(r'٣|3|ثال|تال', value_lower):
            return "third primary (Elementary School)"
        elif re.search(r'٤|4|رابع', value_lower):
            return "Fourth primary (Elementary School)"
        elif re.search(r'٥|5|خمس|خامس', value_lower):
            return "fifth primary (Elementary School)"
        elif re.search(r'سات|6|ساد', value_lower):
            return "Sixth primary (Elementary School)"
        elif re.search(r'ساب|7|٧', value_lower):
            return "first Year of Middle School"
        elif re.search(r'تامن|ثامن|8|٨', value_lower):
            return "second Year of Middle School"
        elif re.search(r'تاس|9|٩', value_lower):
            return "Third Year of Middle School"
        else:
            return "n/a"
    elif re.search(r'متخرج|دبلوم|بكال|دبلوم|قسم|خلص|خريج', value_lower):
        return "Graduate"
    elif re.search(r'جونيور|بتدائى|unior|rimary|٢ب|بتدائي', value_lower):
        if re.search(r'ولي|1|١|اول', value_lower):
            return "first primary (Elementary School)"
        elif re.search(r'ثانى|٢|2|ثاني|تاني', value_lower):
            return "second primary (Elementary School)"
        elif re.search(r'ثالت|٣|3|ثالث|تالت', value_lower):
            return "third primary (Elementary School)"
        elif re.search(r'راب|٤|4|رابع', value_lower):
            return "Fourth primary (Elementary School)"
        elif re.search(r'٥|5|خمس|خامس', value_lower):
            return "fifth primary (Elementary School)"
        elif re.search(r'سات|6|سادس', value_lower):
            return "Sixth primary (Elementary School)"
        else:
            return "n/a"
    elif re.search(r'متوسط|prep|عداد', value_lower):
        if re.search(r'1|١|ول', value_lower):
            return "first Year of Middle School"
        elif re.search(r'ثاني|٢|2|ثانى|تاني', value_lower):
            return "second Year of Middle School"
        elif re.search(r'ثلاث|٣|3|ثالث|تالت', value_lower):
            return "Third Year of Middle School"
        else:
            return "n/a"
    elif re.search(r'ثانوى|ثنوي|ثانوي', value_lower):
        if re.search(r'او|1|١|ول', value_lower):
            return "first General Secondary Education"
        elif re.search(r'ثانى|٢|2|ثاني|تاني', value_lower):
            return "second General Secondary Education"
        elif re.search(r'ثالت|٣|3|ثالث|تالت', value_lower):
            return "Third General Secondary Education"
        else:
            return "n/a"
    elif re.search(r'كلي|قسم|كلى|جامع', value_lower):
        if re.search(r'1|١|ول', value_lower):
            return "First Year of High School"
        elif re.search(r'٢|2|ثاني|تانى', value_lower):
            return "second  Year of High School"
        elif re.search(r'٣|3|ثالث|تالت', value_lower):
            return "third Year of High School"
        elif re.search(r'٤|4|رابع', value_lower):
            return "Fourth Year of High School"
        else:
            return "n/a"
    elif re.search(r'كجي|كى جى|سنه|fs|حضانه|كيجي|تمهيدي|كي جي|kg|كيجى|كجى', value_lower):
        return "Kindergarten"
    
    else:
        return "n/a"

df["السنة الدراسية"] = df["السنة الدراسية"].apply(funuii)

df["السنة الدراسية"].unique()
# Out:
# array(['second primary (Elementary School)',
#        'first primary (Elementary School)',
#        'second General Secondary Education',
#        'first General Secondary Education',
#        'third primary (Elementary School)',
#        'second Year of Middle School',
#        'fifth primary (Elementary School)',
#        'Sixth primary (Elementary School)', 'First Year of High School',
#        'Fourth Year of High School', 'Kindergarten', 'Graduate',
#        'Third General Secondary Education', 'Third Year of Middle School',
#        'first Year of Middle School',
#        'Fourth primary (Elementary School)', 'n/a',
#        'second  Year of High School'], dtype=object)

# %%
import re

def funuoi(valuee):
    for i in range(len(df)):
        value = str(df.at[i, "مكان السكن"]).lower()
        if re.search(r'معادي|نصر|مستقبل|مايو|helwan|heliopolis|شيرات|مباب|شروق|sherouk|رمضان|حلوان|زينب|قاهر',value):
            df.at[i,"مكان السكن"] = "cairo"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'دمياط',value):
            df.at[i,"مكان السكن"] = "Damietta"
            df.at[i,"بلد الإقامة"] = "eygpt"  
        elif re.search(r'كتوبر',value):
            df.at[i,"مكان السكن"] = "6th of October City"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'طنطا',value):
            df.at[i,"مكان السكن"] = "Tanta"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'قنا',value):
            df.at[i,"مكان السكن"] = "Qena"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'ismailia|سماع',value):
            df.at[i,"مكان السكن"] = "Ismailia"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'زقازيق|عين شمس|شرق',value):
            df.at[i,"مكان السكن"] = "Eastern"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'سويس',value):
            df.at[i,"مكان السكن"] = "seuz"
            df.at[i,"بلد الإقامة"] = "eygpt"    
        elif re.search(r'سكمدري|سكندر|alex',value):
            df.at[i,"مكان السكن"] = "Alexandria"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'عبور|الخيمه|قليوبيه',value):
            df.at[i,"مكان السكن"] = "Qalyubia"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'جنوب سيناء',value):
            df.at[i,"مكان السكن"] = "South Sinai"
            df.at[i,"بلد الإقامة"] = "eygpt" 
        elif re.search(r'شمال سيناء',value):
            df.at[i,"مكان السكن"] = "north Sinai"
            df.at[i,"بلد الإقامة"] = "eygpt" 
        elif re.search(r'خفجي',value):
            df.at[i,"مكان السكن"] = "Khafji"
            df.at[i,"بلد الإقامة"] = "suadia arab"   
        elif re.search(r'دقهلي',value):
            df.at[i,"مكان السكن"] = "Dakahlia"
            df.at[i,"بلد الإقامة"] = "eygpt" 
        elif re.search(r'الكويت',value):
            df.at[i,"مكان السكن"] = "Kuwait"
            df.at[i,"بلد الإقامة"] = "Kuwait"
        elif re.search(r'رياض',value):
            df.at[i,"مكان السكن"] = "Riyadh"
            df.at[i,"بلد الإقامة"] = "Riyadh"
        elif re.search(r'منصورة',value):
            df.at[i,"مكان السكن"] = "Mansoura"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'شيخ زايد|فيص|جيز|هرم',value):
            df.at[i,"مكان السكن"] = "Geza"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'مصر',value):
            df.at[i,"مكان السكن"] = "eygpt"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'منيا',value):
            df.at[i,"مكان السكن"] = "Minya"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'دمام',value):
            df.at[i,"مكان السكن"] = "Dammam"
            df.at[i,"بلد الإقامة"] = "suadia arab"
        elif re.search(r'بورس',value):
            df.at[i,"مكان السكن"] = "Port Said"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'فيوم',value):
            df.at[i,"مكان السكن"] = "Faiyum"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'سويف',value):
            df.at[i,"مكان السكن"] = "Beni Suef"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'مطروح',value):
            df.at[i,"مكان السكن"] = "Marsa Matruh"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'سوان',value):
            df.at[i,"مكان السكن"] = "Aswan"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'محله|mahalla|ميت غمر',value):
                df.at[i,"مكان السكن"] = "Gharbia"
                df.at[i,"بلد الإقامة"] = "eygpt"  
        elif re.search(r'sohag',value):
            df.at[i,"مكان السكن"] = "sohag"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'مكة|haram',value):
            df.at[i,"مكان السكن"] = "mecca"
            df.at[i,"بلد الإقامة"] = "sudia arab"
        elif re.search(r'التجمع',value):
            df.at[i,"مكان السكن"] = "new cairo"
            df.at[i,"بلد الإقامة"] = "eygpt"  
        elif re.search(r'sheikh|كفرالشيخ',value):
            df.at[i,"مكان السكن"] = "Kafr al-Sheikh"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'شبرا|قليوب',value):
            df.at[i,"مكان السكن"] = "Qalyubia"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'monofiya|منوفي',value):
            df.at[i,"مكان السكن"] = "Menofia"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'طائف',value):
            df.at[i,"مكان السكن"] = "Taif"
            df.at[i,"بلد الإقامة"] = "suadia arab"
        elif re.search(r'سعودي',value):
            df.at[i,"مكان السكن"] = "suadia arab"
            df.at[i,"بلد الإقامة"] = "suadia arab"    
        elif re.search(r'اقصر',value):
            df.at[i,"مكان السكن"] = "Luxor "
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'بسيون',value):
            df.at[i,"مكان السكن"] = "Gharbia "
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'اسيوط',value):
            df.at[i,"مكان السكن"] = "Asyut "
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'سوهاج',value):
            df.at[i,"مكان السكن"] = "Sohag"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'بحيرة',value):
            df.at[i,"مكان السكن"] = "Beheira"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'swan',value):
            df.at[i,"مكان السكن"] = "Aswan"
            df.at[i,"بلد الإقامة"] = "eygpt"
        elif re.search(r'اردن',value):
            df.at[i,"مكان السكن"] = "Jordan"
            df.at[i,"بلد الإقامة"] = "Jordan"
        elif re.search(r'حولي',value):
            df.at[i,"مكان السكن"] = "Hawalli"
            df.at[i,"بلد الإقامة"] = "Kuwait"
        elif re.search(r'رأس غارب',value):
            df.at[i,"مكان السكن"] = "Red Sea"
            df.at[i,"بلد الإقامة"] = "eygpt"
        else:
            df.at[i,"مكان السكن"] = "na"
            df.at[i,"بلد الإقامة"] = "na"



# Example usage:
# Assuming i is the row index in your DataFrame
# Replace 'value' with the actual column name or value in your DataFrame

funuoi("مكان السكن")
    




df["بلد الإقامة"].unique()
# Out:
# array(['suadia arab', 'na', 'eygpt', 'Riyadh', 'Kuwait', 'sudia arab',
#        'Jordan'], dtype=object)

# %%
df["مكان السكن"].unique()
# Out:
# array(['Khafji', 'na', 'Eastern', 'Qalyubia', 'Dakahlia', 'Damietta',
#        'Riyadh', 'Kuwait', 'Geza', 'Mansoura', 'eygpt', 'Port Said',
#        'Dammam', 'Minya', 'Beni Suef', 'Marsa Matruh', 'Tanta', 'cairo',
#        'Gharbia', 'Qena', 'mecca', 'new cairo', 'Menofia', 'Ismailia',
#        'Faiyum', 'Aswan', 'Kafr al-Sheikh', 'Alexandria',
#        '6th of October City', 'Luxor ', 'Beheira', 'Asyut ', 'Sohag',
#        'sohag', 'Taif', 'seuz', 'suadia arab', 'Hawalli', 'Jordan',
#        'Gharbia ', 'north Sinai', 'Red Sea', 'South Sinai'], dtype=object)

# %%
keywords = ['القاعدة النورانية','كورس اللغة الإنجليزية' ,'كورس اللغة الألمانية', 'دبلومة البرمجة المتخصصة', 'القارئ المثقف','الرياضيات ( الماتيفيك )','مبدائ البرمجة التأسيسية','مستكشفة الألمانية','المدرسة الاونلاين','المستكشف الصغير','دبلومة الجرافكس','دبلومة الديجتال ماركتنج']

for keyword in keywords:
    df[keyword] = df["ما هي الخدمات التعليمية التي تود الاشتراك أو الاستفسار عنها؟"].str.contains(keyword,case=True)
df.drop("ما هي الخدمات التعليمية التي تود الاشتراك أو الاستفسار عنها؟", axis=1, inplace=True)
df
# Out:
# C:\Users\maraw\AppData\Local\Temp\ipykernel_16376\817514348.py:4: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df[keyword] = df["ما هي الخدمات التعليمية التي تود الاشتراك أو الاستفسار عنها؟"].str.contains(keyword,case=True)
#                          السنة الدراسية هل ترى التعليم عن بعد مفيد ومهم؟  \
# 0    second primary (Elementary School)                              Yes
# 1     first primary (Elementary School)                              Yes
# 2    second General Secondary Education                               no
# 3     first General Secondary Education                              Yes
# 4     third primary (Elementary School)                            maybe
# ..                                  ...                              ...
# 145                            Graduate                              Yes
# 146                            Graduate                              Yes
# ...

# %%
import pandas as pd

# Example DataFrame
column_mapping = {
    'السنة الدراسية': 'Academic Year',
    'هل ترى التعليم عن بعد مفيد ومهم؟': 'Is Online Education Useful?',
    'من أين علمت عن جينيس؟': 'Learned About Genius From',
    'مكان السكن': 'Place of Residence',
    'بلد الإقامة': 'Country',
    'id': 'ID',
    'القاعدة النورانية': 'Qaida Nuraniya',
    'كورس اللغة الإنجليزية': 'English Language Course',
    'كورس اللغة الألمانية': 'German Language Course',
    'دبلومة البرمجة المتخصصة': 'Specialized Programming Diploma',
    'الرياضيات ( الماتيفيك )': 'Mathematics (Matific)',
    'مبدائ البرمجة التأسيسية': 'Fundamentals of Programming',
    'مستكشفة الألمانية': 'German Explorer',
    'المدرسة الاونلاين': 'Online School',
    'المستكشف الصغير': 'Little Explorer',
    'دبلومة الجرافكس': 'Graphics Diploma',
    'دبلومة الديجتال ماركتنج': 'Digital Marketing Diploma',
    'القارئ المثقف':"Cultured Reader"

}

# Rename columns using the mapping dictionary
df = df.rename(columns=column_mapping)





# Display the updated DataFrame
print(df)
# Out:
#                           Academic Year Is Online Education Useful?  \
# 0    second primary (Elementary School)                         Yes
# 1     first primary (Elementary School)                         Yes
# 2    second General Secondary Education                          no
# 3     first General Secondary Education                         Yes
# 4     third primary (Elementary School)                       maybe
# ..                                  ...                         ...
# 145                            Graduate                         Yes
# 146                            Graduate                         Yes
# 147         first Year of Middle School                         Yes
# 148  second primary (Elementary School)                       maybe
# 149   Sixth primary (Elementary School)                       maybe
#
#     Learned About Genius From   Place of Residence      Country    ID  year  \
# ...

# %%
df
# Out:
#                           Academic Year Is Online Education Useful?  \
# 0    second primary (Elementary School)                         yes
# 1     first primary (Elementary School)                         yes
# 2    second General Secondary Education                          no
# 3     first General Secondary Education                         yes
# 4     third primary (Elementary School)                       maybe
# ..                                  ...                         ...
# 145                            Graduate                         yes
# 146                            Graduate                         yes
# 147         first Year of Middle School                         yes
# 148  second primary (Elementary School)                       maybe
# 149   Sixth primary (Elementary School)                       maybe
#
#     Learned About Genius From   Place of Residence      Country    ID  year  \
# ...

# %%
df.to_csv('maro_cleand1.csv')
