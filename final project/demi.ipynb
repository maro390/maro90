# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\maraw\OneDrive\Desktop\final project\marawanRadi.csv")
x = df["السنة الدراسية"].unique()
y= df
x
# Out:
# array(['الصف الثاني', 'الصف الاول الاعدادي', 'ثانيه ثانوي', 'اولي ثانوي',
#        '٣ ابتدائي', 'الثالت الابتدائي', 'الصف الثالث الاعدادي', 'جريد ٨',
#        'الخامس الابتدائي', 'الصف الثامن', 'الثانى الاعدادى',
#        'السادس الابتدائي', 'أولى كليه', 'رابعه كليه', 'تمهيدي',
#        'ليسانس آداب قسم مكتبات', 'الصف السادس الابتدائي', 'اولي جامعة',
#        'كجي تو', 'الاول الثانوي', 'الثالت الثانوي', 'بكالوريوس تجارة',
#        'دبلوم صناعي', 'كي جي 1', 'الثالث الاعدادي', 'Grade7',
#        'الصف الثاني الثانوي', 'الثاني الاعدادي', 'الصف الرابع الابتدائي',
#        'تالتة اعدادي', 'الصف الثاني الاعدادي', 'الثالث الابتدائي',
#        'الرابع الابتدائى', 'الاول الاعدادي', 'ابتدائى', 'Kg1',
#        'الصف الاول الثانوى الفنى', 'أولى ثانوى', 'تانيه اعدادي',
#        'الصف الاول الثانوي', 'ثانيه ثانوى', 'سادسه', 'كى جى تو', 'Fs2',
#        'اولي اعدادي', 'جريد ٣', 'اولى اعدادي', 'Primary 2', 'الصف السادس',
#        'خريج', 'الصف الخامس الابتدائي', 'جونيور ٤', 'Gr 8', 'Prep 2', '5',
# ...

# %%
import re

for i in range(len(df)):
    value = str(df.at[i, "من أين علمت عن جينيس؟"]).lower()
    if re.search(r'fb|اعلان|فيس|face|بوست|إعلان',value):
        df.at[i, "من أين علمت عن جينيس؟"] = "Facebook"

    elif re.search(r'الانترنت|internet|net|النت|تواصل|ميديا',value):
        df.at[i, "من أين علمت عن جينيس؟"] = "social media"
    elif re.search(r'اليوتيوب',value):
        df.at[i, "من أين علمت عن جينيس؟"] = "youtube"
    elif re.search(r'اهلي|الاصدقاء|friend|الاقارب|صديق|اخت',value):
        df.at[i, "من أين علمت عن جينيس؟"] = "friend"
    else:
        df.at[i, "من أين علمت عن جينيس؟"] = "N/A"


    
    

    value = str(df.at[i, "هل ترى التعليم عن بعد مفيد ومهم؟"])
    if re.search(r'نعم',value):
        df.at[i,"هل ترى التعليم عن بعد مفيد ومهم؟"] = "yes"
    elif re.search(r'لا',value):
        df.at[i,"هل ترى التعليم عن بعد مفيد ومهم؟"] = "no"
    elif re.search(r'ربما',value):
        df.at[i,"هل ترى التعليم عن بعد مفيد ومهم؟"] = "not sure"


    value = str(df.at[i, "مكان السكن"]).lower()
    if re.search(r'معادي|نصر|مستقبل|مايو|helwan|heliopolis|شيرات|مباب|شروق|sherouk|رمضان|حلوان|زينب|قاهر',value):
        df.at[i,"مكان السكن"] = "cairo"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'دمياط',value):
        df.at[i,"مكان السكن"] = "Damietta"
        df.at[i,"بلد الإقامة"] = "eygpt"  
    elif re.search(r'كتوبر',value):
        df.at[i,"مكان السكن"] = "6th of October City"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'طنطا',value):
        df.at[i,"مكان السكن"] = "Tanta"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'قنا',value):
        df.at[i,"مكان السكن"] = "Qena"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'ismailia|سماع',value):
        df.at[i,"مكان السكن"] = "Ismailia"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'زقازيق|عين شمس|شرق',value):
        df.at[i,"مكان السكن"] = "Eastern"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'سويس',value):
        df.at[i,"مكان السكن"] = "seuz"
        df.at[i,"بلد الإقامة"] = "eygpt"    
    elif re.search(r'سكمدري|سكندر|alex',value):
        df.at[i,"مكان السكن"] = "Alexandria"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'عبور|الخيمه|قليوبيه',value):
        df.at[i,"مكان السكن"] = "Qalyubia"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'جنوب سيناء',value):
        df.at[i,"مكان السكن"] = "South Sinai"
        df.at[i,"بلد الإقامة"] = "eygpt" 
    elif re.search(r'شمال سيناء',value):
        df.at[i,"مكان السكن"] = "north Sinai"
        df.at[i,"بلد الإقامة"] = "eygpt" 
    elif re.search(r'خفجي',value):
        df.at[i,"مكان السكن"] = "Khafji"
        df.at[i,"بلد الإقامة"] = "suadia arab"   
    elif re.search(r'دقهلي',value):
        df.at[i,"مكان السكن"] = "Dakahlia"
        df.at[i,"بلد الإقامة"] = "eygpt" 
    elif re.search(r'الكويت',value):
        df.at[i,"مكان السكن"] = "Kuwait"
        df.at[i,"بلد الإقامة"] = "Kuwait"
    elif re.search(r'رياض',value):
        df.at[i,"مكان السكن"] = "Riyadh"
        df.at[i,"بلد الإقامة"] = "Riyadh"
    elif re.search(r'منصورة',value):
        df.at[i,"مكان السكن"] = "Mansoura"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'شيخ زايد|فيص|جيز|هرم',value):
        df.at[i,"مكان السكن"] = "Geza"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'مصر',value):
        df.at[i,"مكان السكن"] = "eygpt"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'منيا',value):
        df.at[i,"مكان السكن"] = "Minya"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'دمام',value):
        df.at[i,"مكان السكن"] = "Dammam"
        df.at[i,"بلد الإقامة"] = "suadia arab"
    elif re.search(r'بورس',value):
        df.at[i,"مكان السكن"] = "Port Said"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'فيوم',value):
        df.at[i,"مكان السكن"] = "Faiyum"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'سويف',value):
        df.at[i,"مكان السكن"] = "Beni Suef"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'مطروح',value):
        df.at[i,"مكان السكن"] = "Marsa Matruh"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'سوان',value):
        df.at[i,"مكان السكن"] = "Aswan"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'محله|mahalla|ميت غمر',value):
            df.at[i,"مكان السكن"] = "Gharbia"
            df.at[i,"بلد الإقامة"] = "eygpt"  
    elif re.search(r'sohag',value):
        df.at[i,"مكان السكن"] = "sohag"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'مكة|haram',value):
        df.at[i,"مكان السكن"] = "mecca"
        df.at[i,"بلد الإقامة"] = "sudia arab"
    elif re.search(r'التجمع',value):
        df.at[i,"مكان السكن"] = "new cairo"
        df.at[i,"بلد الإقامة"] = "eygpt"  
    elif re.search(r'sheikh|كفرالشيخ',value):
        df.at[i,"مكان السكن"] = "Kafr al-Sheikh"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'شبرا|قليوب',value):
        df.at[i,"مكان السكن"] = "Qalyubia"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'monofiya|منوفي',value):
        df.at[i,"مكان السكن"] = "Menofia"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'طائف',value):
        df.at[i,"مكان السكن"] = "Taif"
        df.at[i,"بلد الإقامة"] = "suadia arab"
    elif re.search(r'سعودي',value):
        df.at[i,"مكان السكن"] = "suadia arab"
        df.at[i,"بلد الإقامة"] = "suadia arab"    
    elif re.search(r'اقصر',value):
        df.at[i,"مكان السكن"] = "Luxor "
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'بسيون',value):
        df.at[i,"مكان السكن"] = "Gharbia "
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'اسيوط',value):
        df.at[i,"مكان السكن"] = "Asyut "
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'سوهاج',value):
        df.at[i,"مكان السكن"] = "Sohag"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'بحيرة',value):
        df.at[i,"مكان السكن"] = "Beheira"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'swan',value):
        df.at[i,"مكان السكن"] = "Aswan"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'اردن',value):
        df.at[i,"مكان السكن"] = "Jordan"
        df.at[i,"بلد الإقامة"] = "Jordan"
    elif re.search(r'حولي',value):
        df.at[i,"مكان السكن"] = "Hawalli"
        df.at[i,"بلد الإقامة"] = "Kuwait"
    elif re.search(r'رأس غارب',value):
        df.at[i,"مكان السكن"] = "Red Sea"
        df.at[i,"بلد الإقامة"] = "eygpt"
    else:

        df.at[i,"مكان السكن"] = "Unknown"
        df.at[i,"بلد الإقامة"] = "Unknown"

    value = str(df.at[i, "السنة الدراسية"]).lower()
    
    if re.search(r'جريد|7|8|gr|5|سادس|صف|grade|جريد|جريد',value):
        
        if re.search(r'1|١|ول',value):
            df.at[i, "السنة الدراسية"] = "first primary (Elementary School)"
            
        elif re.search(r'٢|2|ثاني|تاني',value):

            df.at[i, "السنة الدراسية"] = "second primary (Elementary School)"
        elif re.search(r'٣|3|ثالث|تالت',value):

            df.at[i, "السنة الدراسية"] = "third primary (Elementary School)"
        elif re.search(r'٤|4|رابع',value):

            df.at[i, "السنة الدراسية"] = "Fourth primary (Elementary School)"
        


        elif re.search(r'٥|5|خمس|خامس',value):

            df.at[i, "السنة الدراسية"] = "fifth primary (Elementary School)"
        elif re.search(r'سات|6|سادس',value):

            df.at[i, "السنة الدراسية"] = "Sixth primary (Elementary School)"
        elif re.search(r'سابع|7|٧',value):

            df.at[i, "السنة الدراسية"] = "first Year of Middle School"
        elif re.search(r'تامن|ثامن|8|٨',value):

            df.at[i, "السنة الدراسية"] = "second Year of Middle School"
        elif re.search(r'تاسع|9|٩',value):

            df.at[i, "السنة الدراسية"] = "Third Year of Middle School"
        else:

            if re.search(r'متخرج|دبلوم|بكال|دبلوم|قسم|خلص|خريج',value):
                df.at[i, "السنة الدراسية"] = "Graduate"
            else:
                if re.search(r'جونيور|بتدائى|unior|rimary|٢ب|بتدائي',value):
                    if re.search(r'ولي|1|١|اول',value):

                        df.at[i, "السنة الدراسية"] = "first primary (Elementary School)"
                    elif re.search(r'ثانى|٢|2|ثاني|تاني',value):

                        df.at[i, "السنة الدراسية"] = "second primary (Elementary School)"
                    elif re.search(r'ثالت|٣|3|ثالث|تالت',value):

                        df.at[i, "السنة الدراسية"] = "third primary (Elementary School)"
                    elif re.search(r'راب|٤|4|رابع',value):

                        df.at[i, "السنة الدراسية"] = "Fourth primary (Elementary School)"


                    elif re.search(r'٥|5|خمس|خامس',value):

                        df.at[i, "السنة الدراسية"] = "fifth primary (Elementary School)"

                    elif re.search(r'سات|6|سادس',value):

                        df.at[i, "السنة الدراسية"] = "Sixth primary (Elementary School)"
                    else:
                        if re.search(r'متوسط|prep|عداد',value):
                            if re.search(r'1|١|ول',value):

                                df.at[i, "السنة الدراسية"] = "first Year of Middle School"
                            elif re.search(r'ثاني|٢|2|ثانى|تاني',value):

                                df.at[i, "السنة الدراسية"] = "second Year of Middle School"
                            elif re.search(r'ثلاث|٣|3|ثالث|تالت',value):

                                df.at[i, "السنة الدراسية"] = "Third Year of Middle School"
                            else:

                        
                                if re.search(r'ثانوى|ثنوي|ثانوي',value):
                                    if re.search(r'او|1|١|ول',value):

                                        df.at[i, "السنة الدراسية"] = "first General Secondary Education"
                                    elif re.search(r'ثانى|٢|2|ثاني|تاني',value):

                                        df.at[i, "السنة الدراسية"] = "second YGeneral Secondary Education"
                                    elif re.search(r'ثالت|٣|3|ثالث|تالت',value):

                                        df.at[i, "السنة الدراسية"] = "Third General Secondary Education"
                                else:
                                    if re.search(r'كلي|قسم|جامع',value):
                                        
                                        if re.search(r'1|١|ول',value):
                                            df.at[i, "السنة الدراسية"] = "First Year of High School"
                                            
                                        elif re.search(r'٢|2|ثاني|تاني',value):

                                            df.at[i, "السنة الدراسية"] = "second  Year of High School"
                                        elif re.search(r'٣|3|ثالث|تالت',value):

                                            df.at[i, "السنة الدراسية"] = "third Year of High School"
                                        elif re.search(r'٤|4|رابع',value):

                                            df.at[i, "السنة الدراسية"] = "Fourth Year of High School"
                                        else:
        
                                            if re.search(r'كجي|كى جى|سنه|fs|حضانه|كيجي|تمهيدي|كي جي|kg',value):
                                                df.at[i, "السنة الدراسية"] = "Kindergarten"
                                            else:
                                                df.at[i, "السنة الدراسية"] = "na"




    
df["السنة الدراسية"].unique()
# Out:
# array(['second primary (Elementary School)',
#        'first primary (Elementary School)',
#        'second YGeneral Secondary Education',
#        'first General Secondary Education', '٣ ابتدائي',
#        'الثالت الابتدائي', 'third primary (Elementary School)',
#        'second Year of Middle School', 'الخامس الابتدائي',
#        'Sixth primary (Elementary School)', 'First Year of High School',
#        'Fourth Year of High School', 'Kindergarten',
#        'ليسانس آداب قسم مكتبات', 'Third General Secondary Education',
#        'بكالوريوس تجارة', 'دبلوم صناعي', 'Third Year of Middle School',
#        'first Year of Middle School',
#        'Fourth primary (Elementary School)', 'الثالث الابتدائي',
#        'الرابع الابتدائى', 'ابتدائى', 'Primary 2', 'خريج',
#        'fifth primary (Elementary School)', 'جونيور ٤', '٢ب',
#        'تانية ابتدائي', 'متخرجه', 'أولي ابتدائي', 'الصف الثانى الثانوي',
#        'second  Year of High School', 'الاول الابتدائي',
# ...

# %%
import datetime

# Get the current date and time
current_datetime = datetime.datetime.now()
print("Current datetime:", current_datetime)

# Get the current date
current_date = datetime.date.today()
print("Current date:", current_date)

# Create a specific datetime
specific_datetime = datetime.datetime(2022, 1, 1, 12, 0, 0)
print("Specific datetime:", specific_datetime)

# Format a datetime as a string
formatted_datetime = current_datetime.strftime("%Y-%m-%d %H:%M:%S")
print("Formatted datetime:", formatted_datetime)

# Parse a string into a datetime
parsed_datetime = datetime.datetime.strptime("2022-12-31 23:59:59", "%Y-%m-%d %H:%M:%S")
print("Parsed datetime:", parsed_datetime)
# Out:
# Current datetime: 2023-11-07 22:50:04.950723
# Current date: 2023-11-07
# Specific datetime: 2022-01-01 12:00:00
# Formatted datetime: 2023-11-07 22:50:04
# Parsed datetime: 2022-12-31 23:59:59

# %%
array(['القاعدة النورانية',
       'كورس اللغة الإنجليزية, كورس اللغة الألمانية, مبدائ البرمجة التأسيسية, الرياضيات ( الماتيفيك ), المستكشف الصغير',
       'دبلومة البرمجة المتخصصة, كورس اللغة الإنجليزية', nan,
       'مبدائ البرمجة التأسيسية, القارئ المثقف, المستكشف الصغير, القاعدة النورانية',
       'مبدائ البرمجة التأسيسية',
       'المدرسة الاونلاين, دبلومة البرمجة المتخصصة, كورس اللغة الإنجليزية, دبلومة الجرافكس, مبدائ البرمجة التأسيسية, الرياضيات ( الماتيفيك ), القاعدة النورانية',
       'دبلومة البرمجة المتخصصة, دبلومة الجرافكس, مبدائ البرمجة التأسيسية',
       'دبلومة البرمجة المتخصصة, كورس اللغة الإنجليزية, دبلومة الديجتال ماركتنج, دبلومة الجرافكس, مبدائ البرمجة التأسيسية, القارئ المثقف, الرياضيات ( الماتيفيك ), المستكشف الصغير, القاعدة النورانية',
       'دبلومة البرمجة المتخصصة, مبدائ البرمجة التأسيسية',
       'المستكشف الصغير', 'كورس اللغة الإنجليزية',
       'المدرسة الاونلاين, دبلومة البرمجة المتخصصة, كورس اللغة الإنجليزية, دبلومة الديجتال ماركتنج, دبلومة الجرافكس, مبدائ البرمجة التأسيسية',
       'دبلومة البرمجة المتخصصة',
       'دبلومة الديجتال ماركتنج, القارئ المثقف',
       'كورس اللغة الإنجليزية, دبلومة الجرافكس, مبدائ البرمجة التأسيسية',
       'المستكشف الصغير, القاعدة النورانية',
       'دبلومة البرمجة المتخصصة, كورس اللغة الإنجليزية, دبلومة الجرافكس, المستكشف الصغير',
       'دبلومة البرمجة المتخصصة, كورس اللغة الألمانية, دبلومة الجرافكس, مبدائ البرمجة التأسيسية, المستكشف الصغير',
       'الرياضيات ( الماتيفيك ), المستكشف الصغير, القاعدة النورانية',
       'دبلومة الجرافكس, مبدائ البرمجة التأسيسية', 'دبلومة الجرافكس',
       'المدرسة الاونلاين, دبلومة البرمجة المتخصصة, كورس اللغة الإنجليزية, دبلومة الديجتال ماركتنج, مبدائ البرمجة التأسيسية, الرياضيات ( الماتيفيك ), المستكشف الصغير',
       'دبلومة البرمجة المتخصصة, كورس اللغة الإنجليزية, دبلومة الديجتال ماركتنج, مبدائ البرمجة التأسيسية, المستكشف الصغير',
       'دبلومة البرمجة المتخصصة, دبلومة الديجتال ماركتنج, دبلومة الجرافكس, مبدائ البرمجة التأسيسية',
       'المدرسة الاونلاين, دبلومة البرمجة المتخصصة, كورس اللغة الإنجليزية, دبلومة الجرافكس, مبدائ البرمجة التأسيسية, القارئ المثقف, الرياضيات ( الماتيفيك ), المستكشف الصغير, القاعدة النورانية',
       'دبلومة الديجتال ماركتنج, دبلومة الجرافكس, مبدائ البرمجة التأسيسية',
       'المدرسة الاونلاين, مبدائ البرمجة التأسيسية',
       'كورس اللغة الألمانية, المستكشف الصغير',
       'دبلومة البرمجة المتخصصة, دبلومة الديجتال ماركتنج, كورس اللغة الألمانية, دبلومة الجرافكس, مبدائ البرمجة التأسيسية',
       'المدرسة الاونلاين, دبلومة البرمجة المتخصصة, كورس اللغة الإنجليزية, دبلومة الديجتال ماركتنج, كورس اللغة الألمانية, دبلومة الجرافكس, مبدائ البرمجة التأسيسية, القارئ المثقف, الرياضيات ( الماتيفيك ), المستكشف الصغير, القاعدة النورانية',
       'دبلومة البرمجة المتخصصة, دبلومة الجرافكس',
       'دبلومة البرمجة المتخصصة, كورس اللغة الإنجليزية, مبدائ البرمجة التأسيسية, المستكشف الصغير',
       'المدرسة الاونلاين, كورس اللغة الإنجليزية, دبلومة الجرافكس, مبدائ البرمجة التأسيسية, القارئ المثقف, الرياضيات ( الماتيفيك ), المستكشف الصغير, القاعدة النورانية',
       'دبلومة البرمجة المتخصصة, دبلومة الديجتال ماركتنج, دبلومة الجرافكس, مبدائ البرمجة التأسيسية, القارئ المثقف, المستكشف الصغير',
       'كورس اللغة الألمانية, القاعدة النورانية',
       'المدرسة الاونلاين, دبلومة البرمجة المتخصصة, دبلومة الديجتال ماركتنج',
       'دبلومة البرمجة المتخصصة, كورس اللغة الإنجليزية, الرياضيات ( الماتيفيك )',
       'دبلومة البرمجة المتخصصة, المستكشف الصغير',
       'دبلومة البرمجة المتخصصة, دبلومة الديجتال ماركتنج, مبدائ البرمجة التأسيسية',
       'الرياضيات ( الماتيفيك )',
       'كورس اللغة الإنجليزية, مبدائ البرمجة التأسيسية',
       'المدرسة الاونلاين, مبدائ البرمجة التأسيسية, القارئ المثقف, المستكشف الصغير',
       'دبلومة البرمجة المتخصصة, كورس اللغة الإنجليزية, دبلومة الديجتال ماركتنج, مبدائ البرمجة التأسيسية',
       'المدرسة الاونلاين, دبلومة البرمجة المتخصصة, كورس اللغة الإنجليزية, دبلومة الديجتال ماركتنج, دبلومة الجرافكس, مبدائ البرمجة التأسيسية, القارئ المثقف, الرياضيات ( الماتيفيك ), المستكشف الصغير, القاعدة النورانية',
       'المدرسة الاونلاين, المستكشف الصغير',
       'دبلومة البرمجة المتخصصة, كورس اللغة الإنجليزية, دبلومة الديجتال ماركتنج, كورس اللغة الألمانية, دبلومة الجرافكس',
       'دبلومة البرمجة المتخصصة, دبلومة الديجتال ماركتنج, مبدائ البرمجة التأسيسية, القارئ المثقف, المستكشف الصغير, القاعدة النورانية',
       'كورس اللغة الإنجليزية, مبدائ البرمجة التأسيسية, الرياضيات ( الماتيفيك ), المستكشف الصغير',
       'كورس اللغة الإنجليزية, كورس اللغة الألمانية, مبدائ البرمجة التأسيسية, القارئ المثقف',
       'دبلومة الديجتال ماركتنج, دبلومة الجرافكس, مبدائ البرمجة التأسيسية, القارئ المثقف',
       'دبلومة الجرافكس, مبدائ البرمجة التأسيسية, القارئ المثقف',
       'دبلومة البرمجة المتخصصة, كورس اللغة الإنجليزية, دبلومة الجرافكس',
       'دبلومة البرمجة المتخصصة, دبلومة الجرافكس, مبدائ البرمجة التأسيسية, الرياضيات ( الماتيفيك ), المستكشف الصغير',
       'المدرسة الاونلاين, كورس اللغة الإنجليزية, مبدائ البرمجة التأسيسية',
       'دبلومة البرمجة المتخصصة, كورس اللغة الإنجليزية, كورس اللغة الألمانية',
       'دبلومة الديجتال ماركتنج',
       'المدرسة الاونلاين, دبلومة البرمجة المتخصصة, كورس اللغة الإنجليزية, دبلومة الجرافكس, مبدائ البرمجة التأسيسية, القارئ المثقف, الرياضيات ( الماتيفيك ), المستكشف الصغير',
       'دبلومة البرمجة المتخصصة, كورس اللغة الإنجليزية, دبلومة الديجتال ماركتنج, دبلومة الجرافكس, مبدائ البرمجة التأسيسية',
       'المدرسة الاونلاين, كورس اللغة الإنجليزية, دبلومة الجرافكس, القارئ المثقف, المستكشف الصغير',
       'المدرسة الاونلاين, دبلومة البرمجة المتخصصة, كورس اللغة الإنجليزية, مبدائ البرمجة التأسيسية, الرياضيات ( الماتيفيك )',
       'دبلومة البرمجة المتخصصة, كورس اللغة الألمانية, مبدائ البرمجة التأسيسية, القارئ المثقف',
       'كورس اللغة الإنجليزية, المستكشف الصغير, القاعدة النورانية',
       'دبلومة البرمجة المتخصصة, كورس اللغة الإنجليزية, دبلومة الديجتال ماركتنج, دبلومة الجرافكس, مبدائ البرمجة التأسيسية,

# %%
plt.figure(figsize=(40, 40))
po=df["مكان السكن"].value_counts()
plt.pie(po.values, labels=po.index, autopct='%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x1ca57733d50>,
# ...
#  [Text(0.9409006886662851, 0.5698297061994142, 'cairo'),
#   Text(0.2511859724962001, 1.0709367895544248, 'Alexandria'),
#   Text(-0.27355884495765276, 1.0654414851813472, 'na'),
#   Text(-0.7011663657106891, 0.8475645860912691, 'Qalyubia'),
#   Text(-0.9852829336684331, 0.489098702330855, 'Geza'),
#   Text(-1.0978294013681003, 0.06906956994045171, 'Eastern'),
#   Text(-1.0709367924941409, -0.2511859599626577, 'Damietta'),
#   Text(-0.9953097513542603, -0.46835723423378534, 'eygpt'),
#   Text(-0.8899186801919163, -0.6465637962687656, 'Tanta'),
#   Text(-0.7696296548198938, -0.7859199669316281, 'Beni Suef'),
#   Text(-0.6277848980953208, -0.9032641483660513, 'Gharbia'),
#   Text(-0.468357187639973, -0.9953097732796434, 'Ismailia'),
#   Text(-0.2958117631638918, -1.0594788345096233, 'Port Said'),
#   Text(-0.1378665155389158, -1.0913261766736644, 'Faiyum'),
#   Text(3.86210371883183e-08, -1.0999999999999994, 'suadia arab'),
# ...

# %%
def funuiu(value):
    value_lower = value.lower()

    if re.search(r'معادي|نصر|مستقبل|مايو|helwan|heliopolis|شيرات|مباب|شروق|sherouk|رمضان|حلوان|زينب|قاهر', value_lower):
        return "cairo"
    elif re.search(r'دمياط',value_lower ):
        return "Damietta"
    elif re.search(r'كتوبر', value_lower):
        return "6th of October City"
    elif re.search(r'طنطا', value_lower):
        return "Tanta"
    elif re.search(r'قنا', value_lower):
        return "Qena"
    elif re.search(r'ismailia|سماع', value_lower):
        return "Ismailia"
    elif re.search(r'زقازيق|عين شمس|شرق', value_lower):
        return "Eastern"
    elif re.search(r'سويس', value_lower):
        return "seuz"
    elif re.search(r'سكمدري|سكندر|alex', value_lower):
        return "Alexandria"
    elif re.search(r'عبور|الخيمه|قليوبيه', value_lower):
        return "Qalyubia"
    elif re.search(r'جنوب سيناء', value_lower):
        return "South Sinai"
    elif re.search(r'شمال سيناء', value_lower):
        return "north Sinai"
    elif re.search(r'خفجي', value_lower):
        return "Khafji"
    elif re.search(r'دقهلي', value_lower):
        return "Dakahlia"
    elif re.search(r'الكويت', value_lower):
        return "Kuwait"
    elif re.search(r'رياض', value_lower):
        return "Riyadh"
    elif re.search(r'منصورة', value_lower):
        return "Mansoura"
      

    elif re.search(r'شيخ زايد|فيص|جيز|هرم', value_lower):
        return "Geza"
    elif re.search(r'مصر', value_lower):
        return "eygpt"
    elif re.search(r'منيا', value_lower):
        return "Minya"
    elif re.search(r'دمام', value_lower):
        return "Dammam"
    elif re.search(r'بورس', value_lower):
        return "Port Said"
    elif re.search(r'فيوم', value_lower):
        return "Faiyum"
    elif re.search(r'سويف', value_lower):
        return "Beni Suef"
    elif re.search(r'مطروح', value_lower):
        return "Marsa Matruh"
    elif re.search(r'سوان', value_lower):
        return "Aswan"
    elif re.search(r'محله|mahalla|ميت غمر', value_lower):
        return "Gharbia"
    elif re.search(r'sohag', value_lower):
        return "sohag"
    elif re.search(r'مكة|haram', value_lower):
        return "mecca"
    elif re.search(r'التجمع', value_lower):
        return "new cairo"
    elif re.search(r'sheikh|كفرالشيخ', value_lower):
        return "Kafr al-Sheikh"
    elif re.search(r'شبرا|قليوب', value_lower):
        return "Qalyubia"
    elif re.search(r'monofiya|منوفي', value_lower):
        return "Menofia"
    elif re.search(r'طائف', value_lower):
        return "Taif"
    elif re.search(r'سعودي', value_lower):
        return "suadia arab"
    elif re.search(r'اقصر', value_lower):
        return "Luxor"
    elif re.search(r'بسيون', value_lower):
        return "Gharbia"
    elif re.search(r'اسيوط', value_lower):
        return "Asyut"
    elif re.search(r'سوهاج', value_lower):
        return "Sohag"
    elif re.search(r'بحيرة', value_lower):
        return "Beheira"
    elif re.search(r'swan', value_lower):
        return "Aswan"
    elif re.search(r'اردن', value_lower):
        return "Jordan"
    elif re.search(r'حولي', value_lower):
        return "Hawalli"
    elif re.search(r'رأس غارب', value_lower):
        return "Red Sea"
    else:
        return "Unknown"







df["مكان السكن"] = df["مكان السكن"].astype(str)
df["مكان السكن"] = df["مكان السكن"].apply(funuiu)
df["مكان السكن"].unique()

# %%
import re
df = pd.read_csv(r"C:\Users\maraw\OneDrive\Desktop\final project\marawanRadi.csv")
for i in range(len(df)):
    value = str(df.at[i, "من أين علمت عن جينيس؟"]).lower()
    if re.search(r'fb|اعلان|فيس|face|بوست|إعلان',value):
        df.at[i, "من أين علمت عن جينيس؟"] = "Facebook"

    elif re.search(r'الانترنت|internet|net|النت|تواصل|ميديا',value):
        df.at[i, "من أين علمت عن جينيس؟"] = "social media"
    elif re.search(r'اليوتيوب',value):
        df.at[i, "من أين علمت عن جينيس؟"] = "youtube"
    elif re.search(r'اهلي|الاصدقاء|friend|الاقارب|صديق|اخت',value):
        df.at[i, "من أين علمت عن جينيس؟"] = "friend"
    else:
        df.at[i, "من أين علمت عن جينيس؟"] = "N/A"


    
    

  


    value = str(df.at[i, "مكان السكن"]).lower()
    if re.search(r'معادي|نصر|مستقبل|مايو|helwan|heliopolis|شيرات|مباب|شروق|sherouk|رمضان|حلوان|زينب|قاهر',value):
        df.at[i,"مكان السكن"] = "cairo"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'دمياط',value):
        df.at[i,"مكان السكن"] = "Damietta"
        df.at[i,"بلد الإقامة"] = "eygpt"  
    elif re.search(r'كتوبر',value):
        df.at[i,"مكان السكن"] = "6th of October City"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'طنطا',value):
        df.at[i,"مكان السكن"] = "Tanta"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'قنا',value):
        df.at[i,"مكان السكن"] = "Qena"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'ismailia|سماع',value):
        df.at[i,"مكان السكن"] = "Ismailia"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'زقازيق|عين شمس|شرق',value):
        df.at[i,"مكان السكن"] = "Eastern"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'سويس',value):
        df.at[i,"مكان السكن"] = "seuz"
        df.at[i,"بلد الإقامة"] = "eygpt"    
    elif re.search(r'سكمدري|سكندر|alex',value):
        df.at[i,"مكان السكن"] = "Alexandria"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'عبور|الخيمه|قليوبيه',value):
        df.at[i,"مكان السكن"] = "Qalyubia"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'جنوب سيناء',value):
        df.at[i,"مكان السكن"] = "South Sinai"
        df.at[i,"بلد الإقامة"] = "eygpt" 
    elif re.search(r'شمال سيناء',value):
        df.at[i,"مكان السكن"] = "north Sinai"
        df.at[i,"بلد الإقامة"] = "eygpt" 
    elif re.search(r'خفجي',value):
        df.at[i,"مكان السكن"] = "Khafji"
        df.at[i,"بلد الإقامة"] = "suadia arab"   
    elif re.search(r'دقهلي',value):
        df.at[i,"مكان السكن"] = "Dakahlia"
        df.at[i,"بلد الإقامة"] = "eygpt" 
    elif re.search(r'الكويت',value):
        df.at[i,"مكان السكن"] = "Kuwait"
        df.at[i,"بلد الإقامة"] = "Kuwait"
    elif re.search(r'رياض',value):
        df.at[i,"مكان السكن"] = "Riyadh"
        df.at[i,"بلد الإقامة"] = "Riyadh"
    elif re.search(r'منصورة',value):
        df.at[i,"مكان السكن"] = "Mansoura"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'شيخ زايد|فيص|جيز|هرم',value):
        df.at[i,"مكان السكن"] = "Geza"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'مصر',value):
        df.at[i,"مكان السكن"] = "eygpt"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'منيا',value):
        df.at[i,"مكان السكن"] = "Minya"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'دمام',value):
        df.at[i,"مكان السكن"] = "Dammam"
        df.at[i,"بلد الإقامة"] = "suadia arab"
    elif re.search(r'بورس',value):
        df.at[i,"مكان السكن"] = "Port Said"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'فيوم',value):
        df.at[i,"مكان السكن"] = "Faiyum"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'سويف',value):
        df.at[i,"مكان السكن"] = "Beni Suef"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'مطروح',value):
        df.at[i,"مكان السكن"] = "Marsa Matruh"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'سوان',value):
        df.at[i,"مكان السكن"] = "Aswan"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'محله|mahalla|ميت غمر',value):
            df.at[i,"مكان السكن"] = "Gharbia"
            df.at[i,"بلد الإقامة"] = "eygpt"  
    elif re.search(r'sohag',value):
        df.at[i,"مكان السكن"] = "sohag"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'مكة|haram',value):
        df.at[i,"مكان السكن"] = "mecca"
        df.at[i,"بلد الإقامة"] = "sudia arab"
    elif re.search(r'التجمع',value):
        df.at[i,"مكان السكن"] = "new cairo"
        df.at[i,"بلد الإقامة"] = "eygpt"  
    elif re.search(r'sheikh|كفرالشيخ',value):
        df.at[i,"مكان السكن"] = "Kafr al-Sheikh"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'شبرا|قليوب',value):
        df.at[i,"مكان السكن"] = "Qalyubia"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'monofiya|منوفي',value):
        df.at[i,"مكان السكن"] = "Menofia"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'طائف',value):
        df.at[i,"مكان السكن"] = "Taif"
        df.at[i,"بلد الإقامة"] = "suadia arab"
    elif re.search(r'سعودي',value):
        df.at[i,"مكان السكن"] = "suadia arab"
        df.at[i,"بلد الإقامة"] = "suadia arab"    
    elif re.search(r'اقصر',value):
        df.at[i,"مكان السكن"] = "Luxor "
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'بسيون',value):
        df.at[i,"مكان السكن"] = "Gharbia "
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'اسيوط',value):
        df.at[i,"مكان السكن"] = "Asyut "
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'سوهاج',value):
        df.at[i,"مكان السكن"] = "Sohag"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'بحيرة',value):
        df.at[i,"مكان السكن"] = "Beheira"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'swan',value):
        df.at[i,"مكان السكن"] = "Aswan"
        df.at[i,"بلد الإقامة"] = "eygpt"
    elif re.search(r'اردن',value):
        df.at[i,"مكان السكن"] = "Jordan"
        df.at[i,"بلد الإقامة"] = "Jordan"
    elif re.search(r'حولي',value):
        df.at[i,"مكان السكن"] = "Hawalli"
        df.at[i,"بلد الإقامة"] = "Kuwait"
    elif re.search(r'رأس غارب',value):
        df.at[i,"مكان السكن"] = "Red Sea"
        df.at[i,"بلد الإقامة"] = "eygpt"
    else:

        df.at[i,"مكان السكن"] = "Unknown"
        df.at[i,"بلد الإقامة"] = "Unknown"

    value = str(df.at[i, "السنة الدراسية"]).lower()
    
    if re.search(r'جريد|7|8|gr|5|سادس|صف|grade|جريد|جريد',value):
        
        if re.search(r'1|١|ول',value):
            df.at[i, "السنة الدراسية"] = "first primary (Elementary School)"
            
        elif re.search(r'٢|2|ثاني|تاني',value):

            df.at[i, "السنة الدراسية"] = "second primary (Elementary School)"
        elif re.search(r'٣|3|ثالث|تالت',value):

            df.at[i, "السنة الدراسية"] = "third primary (Elementary School)"
        elif re.search(r'٤|4|رابع',value):

            df.at[i, "السنة الدراسية"] = "Fourth primary (Elementary School)"
        


        elif re.search(r'٥|5|خمس|خامس',value):

            df.at[i, "السنة الدراسية"] = "fifth primary (Elementary School)"
        elif re.search(r'سات|6|سادس',value):

            df.at[i, "السنة الدراسية"] = "Sixth primary (Elementary School)"
        elif re.search(r'سابع|7|٧',value):

            df.at[i, "السنة الدراسية"] = "first Year of Middle School"
        elif re.search(r'تامن|ثامن|8|٨',value):

            df.at[i, "السنة الدراسية"] = "second Year of Middle School"
        elif re.search(r'تاسع|9|٩',value):

            df.at[i, "السنة الدراسية"] = "Third Year of Middle School"
        
        elif re.search(r'متخرج|دبلوم|بكال|دبلوم|قسم|خلص|خريج',value):
            df.at[i, "السنة الدراسية"] = "Graduate"
        elif re.search(r'جونيور|بتدائى|unior|rimary|٢ب|بتدائي',value):
            if re.search(r'ولي|1|١|اول',value):

                df.at[i, "السنة الدراسية"] = "first primary (Elementary School)"
            elif re.search(r'ثانى|٢|2|ثاني|تاني',value):

                df.at[i, "السنة الدراسية"] = "second primary (Elementary School)"
            elif re.search(r'ثالت|٣|3|ثالث|تالت',value):

                df.at[i, "السنة الدراسية"] = "third primary (Elementary School)"
            elif re.search(r'راب|٤|4|رابع',value):

                df.at[i, "السنة الدراسية"] = "Fourth primary (Elementary School)"


            elif re.search(r'٥|5|خمس|خامس',value):

                df.at[i, "السنة الدراسية"] = "fifth primary (Elementary School)"

            elif re.search(r'سات|6|سادس',value):

                df.at[i, "السنة الدراسية"] = "Sixth primary (Elementary School)"
        elif re.search(r'متوسط|prep|عداد',value):
            if re.search(r'1|١|ول',value):

                df.at[i, "السنة الدراسية"] = "first Year of Middle School"
            elif re.search(r'ثاني|٢|2|ثانى|تاني',value):

                df.at[i, "السنة الدراسية"] = "second Year of Middle School"
            elif re.search(r'ثلاث|٣|3|ثالث|تالت',value):

                df.at[i, "السنة الدراسية"] = "Third Year of Middle School"
        
        elif re.search(r'ثانوى|ثنوي|ثانوي',value):
            if re.search(r'او|1|١|ول',value):

                df.at[i, "السنة الدراسية"] = "first General Secondary Education"
            elif re.search(r'ثانى|٢|2|ثاني|تاني',value):

                df.at[i, "السنة الدراسية"] = "second General Secondary Education"
            elif re.search(r'ثالت|٣|3|ثالث|تالت',value):

                df.at[i, "السنة الدراسية"] = "Third General Secondary Education"
        elif re.search(r'كلي|قسم|جامع',value):
            
            if re.search(r'1|١|ول',value):
                df.at[i, "السنة الدراسية"] = "First Year of High School"
                
            elif re.search(r'٢|2|ثاني|تاني',value):

                df.at[i, "السنة الدراسية"] = "second  Year of High School"
            elif re.search(r'٣|3|ثالث|تالت',value):

                df.at[i, "السنة الدراسية"] = "third Year of High School"
            elif re.search(r'٤|4|رابع',value):

                df.at[i, "السنة الدراسية"] = "Fourth Year of High School"
            
        elif re.search(r'كجي|كى جى|سنه|fs|حضانه|كيجي|تمهيدي|كي جي|kg',value):
            df.at[i, "السنة الدراسية"] = "Kindergarten"





    
df["السنة الدراسية"].value_counts()
